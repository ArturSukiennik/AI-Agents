# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f'OpenAI API Key found {openai_api_key[:8]}...')
else:
    print('No OpenAI API Key found')
# Out:
# OpenAI API Key found sk-proj-...

# %%
from openai import OpenAI

# %%
openai = OpenAI()

# %%
messages = [{'role': 'user', 'content': 'What is the cure for a cancer'}]

# %%
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)
print(response.choices[0].message.content)
# Out:
# Cancer is a complex group of diseases characterized by the uncontrolled growth and spread of abnormal cells in the body. There is currently no single "cure" for all types of cancer, as the disease can vary significantly depending on the type of cancer, its stage, and individual patient factors. However, various treatment options are available that can effectively manage or sometimes eliminate the disease for some patients.
#
# Common cancer treatment methods include:
#
# 1. **Surgery**: Removing the cancerous tumor and surrounding tissue.
# 2. **Radiation Therapy**: Using high doses of radiation to kill or damage cancer cells.
# 3. **Chemotherapy**: Using drugs to kill cancer cells, often affecting rapidly dividing cells throughout the body.
# 4. **Immunotherapy**: Boosting the body's immune system to better fight cancer.
# 5. **Targeted Therapy**: Using drugs that specifically target cancer cell mutations or markers.
# ...

# %%
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{'role': 'user', 'content': question}]
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

question = response.choices[0].message.content
print(question)
# Out:
# A train leaves a station traveling north at 60 miles per hour. Another train leaves the same station traveling south at 90 miles per hour. At what distance from the station will the two trains be exactly two hours after they depart?

# %%
messages = [{'role': 'user', 'content': question}]
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To find the distance from the station where the two trains will be after 2 hours, we can calculate the distance each train travels in that time.
#
# 1. **Distance traveled by the northbound train**:
#    - Speed = 60 miles per hour
#    - Time = 2 hours
#    - Distance = Speed × Time = \(60 \, \text{miles/hour} \times 2 \, \text{hours} = 120 \, \text{miles}\)
#
# 2. **Distance traveled by the southbound train**:
#    - Speed = 90 miles per hour
#    - Time = 2 hours
#    - Distance = Speed × Time = \(90 \, \text{miles/hour} \times 2 \, \text{hours} = 180 \, \text{miles}\)
#
# 3. **Total distance from the station**:
#    - Since the trains are traveling in opposite directions, we sum the distances:
#    \[
#    120 \, \text{miles} + 180 \, \text{miles} = 300 \, \text{miles}
#    \]
#
# Thus, after 2 hours, the two trains will be **300 miles** apart from the station.

# %%
from IPython.display import Markdown, display
display(Markdown(question))
display(Markdown(answer))
# Out:
# A train leaves a station traveling north at 60 miles per hour. Another train leaves the same station traveling south at 90 miles per hour. At what distance from the station will the two trains be exactly two hours after they depart?
# To find the distance from the station where the two trains will be after 2 hours, we can calculate the distance each train travels in that time.
#
# 1. **Distance traveled by the northbound train**:
#    - Speed = 60 miles per hour
#    - Time = 2 hours
#    - Distance = Speed × Time = \(60 \, \text{miles/hour} \times 2 \, \text{hours} = 120 \, \text{miles}\)
#
# 2. **Distance traveled by the southbound train**:
#    - Speed = 90 miles per hour
#    - Time = 2 hours
#    - Distance = Speed × Time = \(90 \, \text{miles/hour} \times 2 \, \text{hours} = 180 \, \text{miles}\)
#
# 3. **Total distance from the station**:
#    - Since the trains are traveling in opposite directions, we sum the distances:
#    \[
# ...

# %%
question = "Please pick a business area that might bew worth exploring for an Agentic AI oportunity. Specify it in a single sentence"
messages = [{'role': 'user', 'content': question}]
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

business_area = response.choices[0].message.content
print(business_area)
# Out:
# Exploring the area of personalized healthcare, a potential Agentic AI opportunity could involve developing AI-driven virtual health assistants that autonomously analyze patient data to provide tailored treatment recommendations and manage ongoing health conditions.

# %%
question = f"Please present a pain-point in the industry- something challenging that might be ripe for an Agentic AI solution. The industry is as follows: {business_area}."

messages = [{'role': 'user', 'content': question}]
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)
print(response.choices[0].message.content)
# Out:
# ### Pain Point in Personalized Healthcare: Data Fragmentation and Integration
#
# **Challenge:**
# One of the significant challenges in personalized healthcare is the fragmentation of patient data across multiple sources and formats. Patients often receive care from various healthcare providers, specialists, labs, and wellness programs, leading to a disjointed view of their health history. This fragmentation can result in incomplete information, miscommunications, and a lack of coordinated care, which ultimately affects treatment outcomes and patient satisfaction.
#
# **Key Issues:**
# 1. **Inconsistent Data:** Patient data is often stored in different electronic health record (EHR) systems that may not communicate effectively with each other. This inconsistency can lead to gaps in information and delayed or inappropriate treatment decisions.
#
# ...

# %%
question = f"Propose Agentic AI solution in few lines for the given issues: {response}"
messages = [{'role': 'user', 'content': question}]
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)
print(response.choices[0].message.content)
# Out:
# ### Agentic AI Solution for Personalized Healthcare: Autonomous Virtual Health Assistants
#
# **Overview:** An Agentic AI-powered virtual health assistant can unify and streamline fragmented healthcare data by autonomously gathering, analyzing, and synthesizing information from various sources, including electronic health records (EHRs), wearables, and lab results.
#
# **Key Features:**
# 1. **Data Integration and Standardization:** The AI assistant collects and harmonizes patient data from disparate EHR systems and unstructured sources using NLP, providing a comprehensive real-time health profile.
# 2. **Personalized Treatment Plans:** Machine learning algorithms generate customized health recommendations and medication reminders based on the integrated data, taking into account both clinical and social determinants of health.
# ...
